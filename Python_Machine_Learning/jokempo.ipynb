# %%
import random

# %%
def mais_frequente(lista):
    return max(set(lista), key = lista.count)

def jokempo():
    sua_jogada = 0
    jogadas = []
    while(sua_jogada != 4):
        sua_jogada = int(input('''Escolha uma opção (1,2,3,4): \n 1-Pedra \n 2-Papel \n 3-Tesoura \n 4-Sair\n'''))
        if sua_jogada > 0 and sua_jogada < 4: 
            if len(jogadas) < 5: 
                jogadas.append(sua_jogada)
                jogada_maquina = random.randint(1,3)
                vencedor(sua_jogada, jogada_maquina)
            else:
                jogadas.append(sua_jogada)
                opcao_mais_frequente = mais_frequente(jogadas)
                if opcao_mais_frequente == 1: 
                    maquina = 2
                elif opcao_mais_frequente == 2:
                    maquina = 3
                elif opcao_mais_frequente == 3:
                    maquina = 1
                vencedor(sua_jogada, maquina)
        elif sua_jogada == 4:
            print("Finalizando...\n")
        else:
            print("Número inválido. Tente denovo.\n")
   
    
def vencedor(sua_jogada, jogada_maquina):
    opcoes = [ 'Pedra', 'Papel', 'Tesoura']
    print(f"Sua jogada -> {opcoes[sua_jogada-1]}")
    print(f"Jogada da máquina -> {opcoes[jogada_maquina-1]}")
    if sua_jogada == jogada_maquina:
        print(f"Temos um empate.")
    elif(sua_jogada==1 and jogada_maquina==3) or (sua_jogada==3 and jogada_maquina==2) or (sua_jogada==2 and jogada_maquina==1):
        print(f"Você ganhou!\n")
    else:
        print("Você perdeu!\n")

# %%
try:
    jokempo()
except ValueError:
    print("Digite um número válido.\n")
    jokempo()
# Out:
# Escolha uma opção (1,2,3,4):
#  1-Pedra
#  2-Papel
#  3-Tesoura
#  4-Sair
# 1
# Sua jogada -> Pedra
# Jogada da máquina -> Papel
# Você perdeu!
#
# Escolha uma opção (1,2,3,4):
#  1-Pedra
#  2-Papel
#  3-Tesoura
#  4-Sair
# 1
# Sua jogada -> Pedra
# Jogada da máquina -> Papel
# Você perdeu!
#
# Escolha uma opção (1,2,3,4):
#  1-Pedra
#  2-Papel
#  3-Tesoura
#  4-Sair
# 1
# Sua jogada -> Pedra
# Jogada da máquina -> Tesoura
# Você ganhou!
#
# Escolha uma opção (1,2,3,4):
#  1-Pedra
#  2-Papel
#  3-Tesoura
#  4-Sair
# 1
# Sua jogada -> Pedra
# Jogada da máquina -> Pedra
# Temos um empate.
# Escolha uma opção (1,2,3,4):
#  1-Pedra
#  2-Papel
#  3-Tesoura
#  4-Sair
# 1
# Sua jogada -> Pedra
# Jogada da máquina -> Pedra
# Temos um empate.
# Escolha uma opção (1,2,3,4):
#  1-Pedra
#  2-Papel
#  3-Tesoura
#  4-Sair
# 1
# Sua jogada -> Pedra
# Jogada da máquina -> Papel
# Você perdeu!
#
# Escolha uma opção (1,2,3,4):
#  1-Pedra
#  2-Papel
#  3-Tesoura
#  4-Sair
# 1
# Sua jogada -> Pedra
# ...
